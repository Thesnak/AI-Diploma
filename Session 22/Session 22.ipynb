# %%
# Library for plotting the images and the loss function
import matplotlib.pyplot as plt

# We import the data set from tensorflow and build the model there
import tensorflow as tf
from tensorflow.keras import datasets, layers, models

# Download the data set
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0
# Out:
# C:\Users\moham\anaconda3\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 40s 0us/step

# %%
# Define the 10 image classes
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

# Show the first 10 images
plt.figure(figsize=(10,10))
for i in range(10):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # Die CIFAR Labels sind Arrays, deshalb benötigen wir den extra Index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 30, 30, 32)        896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 13, 13, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 6, 6, 64)          0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 4, 4, 64)          36928
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 122,570
# Trainable params: 122,570
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam', 
             loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
             metrics=['accuracy'])

history = model.fit(train_images, train_labels, epochs=10, 
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/10
# 1563/1563 [==============================] - 54s 34ms/step - loss: 1.5789 - accuracy: 0.4231 - val_loss: 1.3403 - val_accuracy: 0.5233
# Epoch 2/10
# 1563/1563 [==============================] - 52s 33ms/step - loss: 1.2150 - accuracy: 0.5696 - val_loss: 1.1440 - val_accuracy: 0.5985
# Epoch 3/10
# 1563/1563 [==============================] - 54s 34ms/step - loss: 1.0678 - accuracy: 0.6185 - val_loss: 1.0418 - val_accuracy: 0.6369
# Epoch 4/10
# 1563/1563 [==============================] - 61s 39ms/step - loss: 0.9667 - accuracy: 0.6560 - val_loss: 0.9770 - val_accuracy: 0.6520
# Epoch 5/10
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.8954 - accuracy: 0.6824 - val_loss: 0.9434 - val_accuracy: 0.6694
# Epoch 6/10
# 1563/1563 [==============================] - 55s 35ms/step - loss: 0.8396 - accuracy: 0.7039 - val_loss: 0.9207 - val_accuracy: 0.6801
# Epoch 7/10
# 1563/1563 [==============================] - 53s 34ms/step - loss: 0.7889 - accuracy: 0.7225 - val_loss: 0.9171 - val_accuracy: 0.6805
# Epoch 8/10
# 1563/1563 [==============================] - 58s 37ms/step - loss: 0.7553 - accuracy: 0.7355 - val_loss: 0.8821 - val_accuracy: 0.6988
# Epoch 9/10
# 1563/1563 [==============================] - 52s 33ms/step - loss: 0.7172 - accuracy: 0.7471 - val_loss: 0.8487 - val_accuracy: 0.7064
# Epoch 10/10
# 1563/1563 [==============================] - 59s 38ms/step - loss: 0.6812 - accuracy: 0.7589 - val_loss: 0.8848 - val_accuracy: 0.7000

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

# %%
import autokeras as ak

(x_train, y_train), (x_test, y_test) = datasets.mnist.load_data()

# %%
# Initialize the image classifier.
clf = ak.ImageClassifier(overwrite=True, max_trials=1)
# Feed the image classifier with training data.
clf.fit(x_train, y_train, epochs=10)


# Predict with the best model.
predicted_y = clf.predict(x_test)
print(predicted_y)


# Evaluate the best model with testing data.
print(clf.evaluate(x_test, y_test))
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C13CFF790> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C13CFF790> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C13CFF8B0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C13CFF8B0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C180ADA60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C180ADA60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C13CFF790> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C13CFF790> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C13CFF4C0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C13CFF4C0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C13CFF8B0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C13CFF8B0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C13DE95E0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C13DE95E0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C13DE9EE0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function unzip_dataset.<locals>.<listcomp>.<lambda> at 0x0000025C13DE9EE0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: module 'gast' has no attribute 'Index'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Traceback (most recent call last):
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\tuner.py", line 158, in _try_build
#     model = self._build_hypermodel(hp)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\tuner.py", line 146, in _build_hypermodel
#     model = self.hypermodel.build(hp)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\graph.py", line 250, in build
#     outputs = block.build(hp, inputs=temp_inputs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\wrapper.py", line 108, in build
#     output_node = self._build_block(hp, output_node, block_type)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\wrapper.py", line 77, in _build_block
#     return basic.ResNetBlock().build(hp, output_node)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\basic.py", line 694, in build
#     input_node = layers.Resizing(
# AttributeError: module 'tensorflow.keras.layers' has no attribute 'Resizing'
# Invalid model 0/5
# Traceback (most recent call last):
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\tuner.py", line 158, in _try_build
#     model = self._build_hypermodel(hp)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\tuner.py", line 146, in _build_hypermodel
#     model = self.hypermodel.build(hp)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\graph.py", line 250, in build
#     outputs = block.build(hp, inputs=temp_inputs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\wrapper.py", line 108, in build
#     output_node = self._build_block(hp, output_node, block_type)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\wrapper.py", line 77, in _build_block
#     return basic.ResNetBlock().build(hp, output_node)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\basic.py", line 694, in build
#     input_node = layers.Resizing(
# AttributeError: module 'tensorflow.keras.layers' has no attribute 'Resizing'
# Invalid model 1/5
# Traceback (most recent call last):
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\tuner.py", line 158, in _try_build
#     model = self._build_hypermodel(hp)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\tuner.py", line 146, in _build_hypermodel
#     model = self.hypermodel.build(hp)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\graph.py", line 250, in build
#     outputs = block.build(hp, inputs=temp_inputs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\wrapper.py", line 108, in build
#     output_node = self._build_block(hp, output_node, block_type)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\wrapper.py", line 77, in _build_block
#     return basic.ResNetBlock().build(hp, output_node)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\basic.py", line 694, in build
#     input_node = layers.Resizing(
# AttributeError: module 'tensorflow.keras.layers' has no attribute 'Resizing'
# Invalid model 2/5
# Traceback (most recent call last):
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\tuner.py", line 158, in _try_build
#     model = self._build_hypermodel(hp)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\tuner.py", line 146, in _build_hypermodel
#     model = self.hypermodel.build(hp)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\graph.py", line 250, in build
#     outputs = block.build(hp, inputs=temp_inputs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\wrapper.py", line 108, in build
#     output_node = self._build_block(hp, output_node, block_type)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\wrapper.py", line 77, in _build_block
#     return basic.ResNetBlock().build(hp, output_node)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\basic.py", line 694, in build
#     input_node = layers.Resizing(
# AttributeError: module 'tensorflow.keras.layers' has no attribute 'Resizing'
# Invalid model 3/5
# Traceback (most recent call last):
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\tuner.py", line 158, in _try_build
#     model = self._build_hypermodel(hp)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\tuner.py", line 146, in _build_hypermodel
#     model = self.hypermodel.build(hp)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\graph.py", line 250, in build
#     outputs = block.build(hp, inputs=temp_inputs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\wrapper.py", line 108, in build
#     output_node = self._build_block(hp, output_node, block_type)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\wrapper.py", line 77, in _build_block
#     return basic.ResNetBlock().build(hp, output_node)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\basic.py", line 694, in build
#     input_node = layers.Resizing(
# AttributeError: module 'tensorflow.keras.layers' has no attribute 'Resizing'
# Invalid model 4/5
# Traceback (most recent call last):
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\tuner.py", line 158, in _try_build
#     model = self._build_hypermodel(hp)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\tuner.py", line 146, in _build_hypermodel
#     model = self.hypermodel.build(hp)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\graph.py", line 250, in build
#     outputs = block.build(hp, inputs=temp_inputs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\wrapper.py", line 108, in build
#     output_node = self._build_block(hp, output_node, block_type)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\wrapper.py", line 77, in _build_block
#     return basic.ResNetBlock().build(hp, output_node)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\engine\block.py", line 38, in _build_wrapper
#     return super()._build_wrapper(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py", line 111, in _build_wrapper
#     return self._build(hp, *args, **kwargs)
#   File "C:\Users\moham\anaconda3\lib\site-packages\autokeras\blocks\basic.py", line 694, in build
#     input_node = layers.Resizing(
# AttributeError: module 'tensorflow.keras.layers' has no attribute 'Resizing'
# Invalid model 5/5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\keras_tuner\engine\tuner.py:158, in Tuner._try_build(self, hp)
#     157 try:
# --> 158     model = self._build_hypermodel(hp)
#     159 except:
#
# File ~\anaconda3\lib\site-packages\keras_tuner\engine\tuner.py:146, in Tuner._build_hypermodel(self, hp)
#     145 with maybe_distribute(self.distribution_strategy):
# --> 146     model = self.hypermodel.build(hp)
#     147     self._override_compile_args(model)
#
# File ~\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py:111, in HyperModel._build_wrapper(self, hp, *args, **kwargs)
#     110     hp = hp.copy()
# --> 111 return self._build(hp, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\autokeras\graph.py:250, in Graph.build(self, hp)
#     246 temp_inputs = [
#     247     keras_nodes[self._node_to_id[input_node]]
#     248     for input_node in block.inputs
#     249 ]
# --> 250 outputs = block.build(hp, inputs=temp_inputs)
#     251 outputs = nest.flatten(outputs)
#
# File ~\anaconda3\lib\site-packages\autokeras\engine\block.py:38, in Block._build_wrapper(self, hp, *args, **kwargs)
#      37 with hp.name_scope(self.name):
# ---> 38     return super()._build_wrapper(hp, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py:111, in HyperModel._build_wrapper(self, hp, *args, **kwargs)
#     110     hp = hp.copy()
# --> 111 return self._build(hp, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\autokeras\blocks\wrapper.py:108, in ImageBlock.build(self, hp, inputs)
#     107     with hp.conditional_scope(BLOCK_TYPE, [block_type]):
# --> 108         output_node = self._build_block(hp, output_node, block_type)
#     109 else:
#
# File ~\anaconda3\lib\site-packages\autokeras\blocks\wrapper.py:77, in ImageBlock._build_block(self, hp, output_node, block_type)
#      76 if block_type == RESNET:
# ---> 77     return basic.ResNetBlock().build(hp, output_node)
#      78 elif block_type == XCEPTION:
#
# File ~\anaconda3\lib\site-packages\autokeras\engine\block.py:38, in Block._build_wrapper(self, hp, *args, **kwargs)
#      37 with hp.name_scope(self.name):
# ---> 38     return super()._build_wrapper(hp, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\keras_tuner\engine\hypermodel.py:111, in HyperModel._build_wrapper(self, hp, *args, **kwargs)
#     110     hp = hp.copy()
# --> 111 return self._build(hp, *args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\autokeras\blocks\basic.py:694, in KerasApplicationBlock.build(self, hp, inputs)
#     693 if input_node.shape[1] < min_size or input_node.shape[2] < min_size:
# --> 694     input_node = layers.Resizing(
#     695         max(min_size, input_node.shape[1]),
#     696         max(min_size, input_node.shape[2]),
#     697     )(input_node)
#     698 if input_node.shape[3] == 1:
#
# AttributeError: module 'tensorflow.keras.layers' has no attribute 'Resizing'
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Input In [21], in <cell line: 4>()
#       2 clf = ak.ImageClassifier(overwrite=True, max_trials=1)
#       3 # Feed the image classifier with training data.
# ----> 4 clf.fit(x_train, y_train, epochs=10)
#       7 # Predict with the best model.
#       8 predicted_y = clf.predict(x_test)
#
# File ~\anaconda3\lib\site-packages\autokeras\tasks\image.py:165, in ImageClassifier.fit(self, x, y, epochs, callbacks, validation_split, validation_data, **kwargs)
#     108 def fit(
#     109     self,
#     110     x: Optional[types.DatasetType] = None,
#    (...)
#     118     **kwargs
#     119 ):
#     120     """Search for the best model and hyperparameters for the AutoModel.
#     121
#     122     It will search for the best model based on the performances on
#    (...)
#     163             validation loss values and validation metrics values (if applicable).
#     164     """
# --> 165     history = super().fit(
#     166         x=x,
#     167         y=y,
#     168         epochs=epochs,
#     169         callbacks=callbacks,
#     170         validation_split=validation_split,
#     171         validation_data=validation_data,
#     172         **kwargs
#     173     )
#     174     return history
#
# File ~\anaconda3\lib\site-packages\autokeras\auto_model.py:292, in AutoModel.fit(self, x, y, batch_size, epochs, callbacks, validation_split, validation_data, verbose, **kwargs)
#     287 if validation_data is None and validation_split:
#     288     dataset, validation_data = data_utils.split_dataset(
#     289         dataset, validation_split
#     290     )
# --> 292 history = self.tuner.search(
#     293     x=dataset,
#     294     epochs=epochs,
#     295     callbacks=callbacks,
#     296     validation_data=validation_data,
#     297     validation_split=validation_split,
#     298     verbose=verbose,
#     299     **kwargs
#     300 )
#     302 return history
#
# File ~\anaconda3\lib\site-packages\autokeras\engine\tuner.py:191, in AutoTuner.search(self, epochs, callbacks, validation_split, verbose, **fit_kwargs)
#     189 hp = self.oracle.get_space()
#     190 self._prepare_model_build(hp, **fit_kwargs)
# --> 191 self._try_build(hp)
#     192 self.oracle.update_space(hp)
#     193 super().search(
#     194     epochs=epochs, callbacks=new_callbacks, verbose=verbose, **fit_kwargs
#     195 )
#
# File ~\anaconda3\lib\site-packages\keras_tuner\engine\tuner.py:166, in Tuner._try_build(self, hp)
#     163     print("Invalid model %s/%s" % (i, MAX_FAIL_STREAK))
#     165     if i == MAX_FAIL_STREAK:
# --> 166         raise RuntimeError("Too many failed attempts to build model.")
#     167     continue
#     169 # Stop if `build()` does not return a valid model.
#
# RuntimeError: Too many failed attempts to build model.
